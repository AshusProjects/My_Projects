# %%
import random
import pandas as pd
First_Name=[]
Middle_Name=[]
Last_Name=[]
Date_of_birth=[]
Acc_No=[]
PIN=[]
Balance=[]
history=[]
Mobile_Number=[]

block_First_Name=[]
block_Middle_Name=[]
block_Last_Name=[]
block_Date_of_birth=[]
block_Acc_No=[]
block_PIN=[]
block_Balance=[]
block_Mobile_Number=[]

def new_account():
    print("-------Fill the information Correctly---------- ")
    FristName=input('Frist Nmae                 : ')
    MiddleName=input('Middle Nmae                : ')
    LastName=input('Last Nmae                  : ')
    MobileNumbaer=int(input('Mobile No.                 : '))
    def generate_account_number():
        while True:
            random_digits = [random.randint(0, 9) for _ in range(9)]
            first_digit = random.randint(1, 9)
            account_number = str(first_digit) + ''.join(map(str, random_digits))
            if account_number not in Acc_No :
                Acc_No.append(int(account_number))
                print("Generated Account Number   : ", account_number)
                return account_number
    def generate_PIN():
        while True:
            random_digits = [random.randint(0, 9) for _ in range(3)]
            first_digit = random.randint(1, 9)
            gen_pin = str(first_digit) + ''.join(map(str, random_digits))
            if gen_pin not in PIN :
                PIN.append(int(gen_pin))
                print("Generated PIN              : ", gen_pin)
                return gen_pin
    balance=int(input('ammount of poening Account : '))
    generate_account_number()
    generate_PIN()
    First_Name.append(FristName)
    Middle_Name.append(MiddleName)
    Last_Name.append(LastName)
    Mobile_Number.append(MobileNumbaer)
    Balance.append(balance)

def cash_deposit():
    print("Enter your account number or Mobile Number to procide ")
    Enter_No=int(input('Acc. No./Mobile No.        : '))  
    if Enter_No in  Acc_No:
        index = Acc_No.index(Enter_No)
        print("Enter your Ammount. ")
        enter_ammount=int(input())
        print("Enter your PIN. ")
        Enter_PIN=int(input())
        if PIN[index]==Enter_PIN:
            updated_Bal=Balance[index]+enter_ammount
            Balance[index]=updated_Bal
            print('your balance is ',updated_Bal)
        else:
            print('-----wrong PIN------')
            print('Entre PIN again ')
            reEnter_PIN=int(input())
            if PIN[index]==reEnter_PIN:
                updated_Bal=Balance[index]+enter_ammount
                Balance[index]=updated_Bal
                print('your balance is ',updated_Bal)
            else:
                print('-----wrong PIN------')
                print('Entre PIN again ')
                reEnter_PIN=int(input())
                if PIN[index]==reEnter_PIN:
                    updated_Bal=Balance[index]+enter_ammount
                    Balance[index]=updated_Bal
                    print('your balance is ',updated_Bal)
                else:
                    print('your acc is blocked')
                    block_First_Name.append(First_Name.pop(index))
                    block_Middle_Name.append(Middle_Name.pop(index))
                    block_Last_Name.append(Last_Name.pop(index))
                    block_Acc_No.append(Acc_No.pop(index))
                    block_PIN.append(PIN.pop(index))
                    block_Balance.append(Balance.pop(index))
                    block_Mobile_Number.append(Mobile_Number.pop(index))
                    
    elif Enter_No in Mobile_Number:
        index = Mobile_Number.index(Enter_No)
        print("Enter your Ammount. ")
        enter_ammount=int(input())
        print("Enter your PIN. ")
        Enter_PIN=int(input())
        if PIN[index]==Enter_PIN:
            updated_Bal=Balance[index]+enter_ammount
            Balance[index]=updated_Bal
            print('your balance is ',updated_Bal)
        else:
            print('-----wrong PIN------')
            print('Entre PIN again ')
            reEnter_PIN=int(input())
            if PIN[index]==reEnter_PIN:
                updated_Bal=Balance[index]+enter_ammount
                Balance[index]=updated_Bal
                print('your balance is ',updated_Bal)
            else:
                print('-----wrong PIN------')
                print('Entre PIN again ')
                reEnter_PIN=int(input())
                if PIN[index]==reEnter_PIN:
                    updated_Bal=Balance[index]+enter_ammount
                    Balance[index]=updated_Bal
                    print('your balance is ',updated_Bal)
                else:
                    print('your acc is blocked')
                    block_First_Name.append(First_Name.pop(index))
                    block_Middle_Name.append(Middle_Name.pop(index))
                    block_Last_Name.append(Last_Name.pop(index))
                    block_Acc_No.append(Acc_No.pop(index))
                    block_PIN.append(PIN.pop(index))
                    block_Balance.append(Balance.pop(index))
                    block_Mobile_Number.append(Mobile_Number.pop(index))
    else:
        print("you entred wrong Acc. No. or Mobile No. please try again or your account is blocked please check again ")
        

def cash_withdrawal():
    print("Enter your account number. ")
    Enter_No=int(input())  
    if Enter_No in  Acc_No:
        index = Acc_No.index(Enter_No)
        print("Enter your Ammount. ")
        enter_ammount=int(input())
        print("Enter your PIN. ")
        Enter_PIN=int(input())
        if PIN[index]==Enter_PIN:
            updated_Bal=Balance[index]-enter_ammount
            Balance[index]=updated_Bal
            if updated_Bal >= 0:  
                Balance[index] = updated_Bal
                print('your balance is ',updated_Bal)
            else :
                print('Insufficient balance ')
        else:
            print('-----wrong PIN------')
            print('Entre PIN again ')
            reEnter_PIN=int(input())
            if PIN[index]==reEnter_PIN:
                updated_Bal=Balance[index]-enter_ammount
                Balance[index]=updated_Bal
                print('your balance is ',updated_Bal)
            else:
                print('-----wrong PIN------')
                print('Entre PIN again ')
                reEnter_PIN=int(input())
                if PIN[index]==reEnter_PIN:
                    updated_Bal=Balance[index]-enter_ammount
                    Balance[index]=updated_Bal
                    print('your balance is ',updated_Bal)
                else:
                    print("Your Account is blocked ")
                    block_First_Name.append(First_Name.pop(index))
                    block_Middle_Name.append(Middle_Name.pop(index))
                    block_Last_Name.append(Last_Name.pop(index))
                    block_Acc_No.append(Acc_No.pop(index))
                    block_PIN.append(PIN.pop(index))
                    block_Balance.append(Balance.pop(index))
                    block_Mobile_Number.append(Mobile_Number.pop(index))
                    
    elif Enter_No in  Mobile_Number:
        index = Mobile_Number.index(Enter_No)
        print("Enter your Ammount. ")
        enter_ammount=int(input())
        print("Enter your PIN. ")
        Enter_PIN=int(input())
        if PIN[index]==Enter_PIN:
            updated_Bal=Balance[index]-enter_ammount
            Balance[index]=updated_Bal
            print('your balance is ',updated_Bal)
        else:
            print('-----wrong PIN------')
            print('Entre PIN again ')
            reEnter_PIN=int(input())
            if PIN[index]==reEnter_PIN:
                updated_Bal=Balance[index]-enter_ammount
                Balance[index]=updated_Bal
                print('your balance is ',updated_Bal)
            else:
                print('-----wrong PIN------')
                print('Entre PIN again ')
                reEnter_PIN=int(input())
                if PIN[index]==reEnter_PIN:
                    updated_Bal=Balance[index]-enter_ammount
                    Balance[index]=updated_Bal
                    print('your balance is ',updated_Bal)
                else:
                    print("Your Account is blocked ")
                    block_First_Name.append(First_Name.pop(index))
                    block_Middle_Name.append(Middle_Name.pop(index))
                    block_Last_Name.append(Last_Name.pop(index))
                    block_Acc_No.append(Acc_No.pop(index))
                    block_PIN.append(PIN.pop(index))
                    block_Balance.append(Balance.pop(index))
                    block_Mobile_Number.append(Mobile_Number.pop(index))
    else:
        print("you entred wrong acc no please try again or your account is blockes please check again. ")
   

def unblock_Acc():
    print('Entre your account number ')
    acc_no=int(input())
    if acc_no in block_Acc_No:
        index=block_Acc_No.index(acc_no)
        print('to un block your account enter PIN')
        pin1=int(input())
        if block_PIN[index]==pin1:
            First_Name.append(block_First_Name.pop(index))
            Middle_Name.append(block_Middle_Name.pop(index))
            Last_Name.append(block_Last_Name.pop(index))
            Acc_No.append(block_Acc_No.pop(index))
            PIN.append(block_PIN.pop(index))
            Balance.append(block_Balance.pop(index))
            Mobile_Number.append(block_Mobile_Number.pop(index))
            print('your account is unblocked')
    else:
        print('you entred wrong acc no please try again or your account is not blockes please check again')

def block_acc():
    print('enter the account no to block')
    acc_no=int(input())
    if acc_no in Acc_No:
        index = Acc_No.index(acc_no)
        block_First_Name.append(First_Name.pop(index))
        block_Middle_Name.append(Middle_Name.pop(index))
        block_Last_Name.append(Last_Name.pop(index))
        block_Acc_No.append(Acc_No.pop(index))
        block_PIN.append(PIN.pop(index))
        block_Balance.append(Balance.pop(index))
        block_Mobile_Number.append(Mobile_Number.pop(index))

    else:
        print('you entred wrong account or your acc is already blocked')

def transfer():
    amm = int(input("Enter the amount: "))
    toACC = int(input("Enter the account number/mobile number you want to transfer money to: "))
    fromACC = int(input("Enter the account number/mobile number you want to transfer money from: "))
    if fromACC in Acc_No or fromACC in Mobile_Number and toACC in Acc_No or toACC in Mobile_Number:
        if fromACC in Acc_No:
            index = Acc_No.index(fromACC)
        else:
            index = Mobile_Number.index(fromACC)
        print("Enter your PIN:")
        Enter_PIN = int(input())
        if PIN[index] == Enter_PIN:
            updated_Bal = Balance[index] - amm
            if updated_Bal >= 0:  
                Balance[index] = updated_Bal
                print('Your balance is: ', updated_Bal)
                if toACC in Acc_No:
                    index1 = Acc_No.index(toACC)
                else:
                    index1 = Mobile_Number.index(toACC)
                update_Bal = Balance[index1] + amm
                Balance[index1] = update_Bal
                print('Transetion Sussessful')
            else:
                print("Insufficient balance for the transaction.")
        else:
            print("You entered the wrong PIN. Please try again.")
    else:
        print("Please enter valid account/mobile numbers. Please try again.")
    

    
def Change_PIN():
    Acc_no=int(input('entre the ACC NO./Mobile Number : '))
    if Acc_no in Acc_No:
        index=Acc_No.index(Acc_no)
        pin=int(input('entre the PIN :  '))
        if PIN[index]==pin:
            New_PIN=int(input('enter the new PIN : '))
            reentre_PIN=int(input('reentre the new PIN : '))
            if New_PIN==reentre_PIN:
                PIN[index]=New_PIN
            else:
                print("please try again")
        else:
            print("you entre wrong pin please try again")
    else :
        print("retyr")

def update_Phone_no():
    Acc_no=int(input('entre the ACC NO./Mobile Number : '))
    if Acc_no in Acc_No:
        index=Acc_No.index(Acc_no)
        pin=int(input('entre the PIN :  '))
        if PIN[index]==pin:
            New_phone_no=int(input('enter the phone number : '))
            reentre_PIN=int(input('reentre the phone number : '))
            if New_phone_no==reentre_PIN:
                PIN[index]=New_phone_no
            else:
                print("please try again")
        else:
            print("you entre wrong pin please try again")
    else :
        print("retyr")



# program loop
while True:
    print('--------------------------------------------------------------------------------------------------------------')
    print("1. New Account")
    print("2. Cash Deposit")
    print("3. Cash Withdrawal")
    print("4. Transfer")
    print("5. Block Account")
    print("6. Unblock Account")
    print("7. Change PIN")
    print("8. Change  Mobile Number")
    print("9. Done")

    choice = input("Enter your choice: ")

    if choice == '1':
        new_account()
    elif choice == '2':
        cash_deposit()
    elif choice == '3':
        cash_withdrawal()
    elif choice == '4':
        transfer()
    elif choice == '5':
        block_acc()
    elif choice == '6':
        unblock_Acc()
    elif choice == '7':
        change_PIN()
    elif choice=='8':
        update_Phone_no()
    elif choice == '9':
        print("Exiting...")
        break
    else:
        print("Invalid choice. Please try again.")


print('List of first name   ',First_Name)
print('list of middle name  ',Middle_Name)
print('list of last name    ',Last_Name)
print('list of acc no       ',Acc_No)
print('list of PIN          ',PIN)
print('list of balance      ',Balance)
print('list of Mobile No.   ',Mobile_Number)

print('List of blocked first name   ',block_First_Name)
print('list of blocked middle name  ',block_Middle_Name)
print('list of blocked last name    ',block_Last_Name)
print('list of blocked acc no       ',block_Acc_No)
print('list of blocked PIN          ',block_PIN)
print('list of blocked balance      ',block_Balance)
print('list of blocked Mobile No.   ',block_Mobile_Number)
# Out:
# --------------------------------------------------------------------------------------------------------------
# 1. New Account
# 2. Cash Deposit
# 3. Cash Withdrawal
# 4. Transfer
# 5. Block Account
# 6. Unblock Account
# 7. Change PIN
# 8. Change  Mobile Number
# 9. Done
# Enter your choice:  9
# Exiting...
# List of first name    []
# list of middle name   []
# list of last name     []
# list of acc no        []
# list of PIN           []
# list of balance       []
# list of Mobile No.    []
# List of blocked first name    []
# list of blocked middle name   []
# list of blocked last name     []
# list of blocked acc no        []
# list of blocked PIN           []
# list of blocked balance       []
# list of blocked Mobile No.    []
